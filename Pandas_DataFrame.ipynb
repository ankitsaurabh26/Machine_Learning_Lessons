# %% [markdown]
# ### Pandas DataFrame

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Creating DataFrame

# %%
# Using list (2D)
student_data = [
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]
pd.DataFrame(student_data, columns=['iq','marks','package'])
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
# Using dicts
student_dict = {
    'iq':[100,120,80,90,0,0],
    'marks':[80,50,70,100,0,0],
    'package':[10,7,14,2,0,0]
}
students = pd.DataFrame(student_dict)
print(students)
# Out:
#     iq  marks  package
# 0  100     80       10
# 1  120     50        7
# 2   80     70       14
# 3   90    100        2
# 4    0      0        0
# 5    0      0        0

# %%
# Using read_csv
movies = pd.read_csv('movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl = pd.read_csv('ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# #### DataFrame Attributes and Methods

# %%
# Shape
ipl.shape
# Out:
# (950, 20)

# %%
movies.shape # (rows, columns)
# Out:
# (1629, 18)

# %%
# dtypes
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
movies.dtypes # Pandas ke lingo mein object = string
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
# index
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
# columns
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
students
# Out:
#     iq  marks  package
# 0  100     80       10
# 1  120     50        7
# 2   80     70       14
# 3   90    100        2
# 4    0      0        0
# 5    0      0        0

# %%
# values
students.values
# Out:
# array([[100,  80,  10],
#        [120,  50,   7],
#        [ 80,  70,  14],
#        [ 90, 100,   2],
#        [  0,   0,   0],
#        [  0,   0,   0]], dtype=int64)

# %%
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
# head and tail
movies.head(6)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
# 5                           Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# ...

# %%
ipl.tail(2)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                  Team2  \
# 948              Kings XI Punjab    Chennai Super Kings
# 949  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver            WinningTeam WonBy  Margin method  \
# 948          bat         N    Chennai Super Kings  Runs    33.0    NaN
# 949        field         N  Kolkata Knight Riders  Runs   140.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 948      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# ...

# %%
# sample -> Randomly data ka idea lena hai to use this
ipl.sample(2)
# Out:
#           ID       City        Date Season MatchNumber  \
# 234  1178395  Bengaluru  2019-04-07   2019          20
# 5    1304115     Mumbai  2022-05-21   2022          69
#
#                            Team1           Team2                     Venue  \
# 234  Royal Challengers Bangalore  Delhi Capitals     M.Chinnaswamy Stadium
# 5                 Delhi Capitals  Mumbai Indians  Wankhede Stadium, Mumbai
#
#          TossWinner TossDecision SuperOver     WinningTeam    WonBy  Margin  \
# 234  Delhi Capitals        field         N  Delhi Capitals  Wickets     4.0
# 5    Mumbai Indians        field         N  Mumbai Indians  Wickets     5.0
#
#     method Player_of_Match                                       Team1Players  \
# 234    NaN        K Rabada  ['PA Patel', 'V Kohli', 'AB de Villiers', 'MP ...
# 5      NaN       JJ Bumrah  ['PP Shaw', 'DA Warner', 'MR Marsh', 'RR Pant'...
#
#                                           Team2Players      Umpire1  \
# ...

# %%
# info 
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# describe
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
# isnull
ipl.isnull()
# Out:
#         ID   City   Date  Season  MatchNumber  Team1  Team2  Venue  \
# 0    False  False  False   False        False  False  False  False
# 1    False  False  False   False        False  False  False  False
# 2    False  False  False   False        False  False  False  False
# 3    False  False  False   False        False  False  False  False
# 4    False  False  False   False        False  False  False  False
# ..     ...    ...    ...     ...          ...    ...    ...    ...
# 945  False  False  False   False        False  False  False  False
# 946  False  False  False   False        False  False  False  False
# 947  False  False  False   False        False  False  False  False
# 948  False  False  False   False        False  False  False  False
# 949  False  False  False   False        False  False  False  False
#
#      TossWinner  TossDecision  SuperOver  WinningTeam  WonBy  Margin  method  \
# 0         False         False      False        False  False   False    True
# ...

# %%
ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
# duplicated
movies.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627    False
# 1628    False
# Length: 1629, dtype: bool

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
students.duplicated().sum()
# Out:
# 1

# %%
# rename -> column ka naam rename kar dega
students
# Out:
#     iq  marks  package
# 0  100     80       10
# 1  120     50        7
# 2   80     70       14
# 3   90    100        2
# 4    0      0        0
# 5    0      0        0

# %%
students.rename(columns={'marks':'percent','package':'LPA'}) # not a permanent change
# Out:
#     iq  percent  LPA
# 0  100       80   10
# 1  120       50    7
# 2   80       70   14
# 3   90      100    2
# 4    0        0    0
# 5    0        0    0

# %%
students.rename(columns={'marks':'percent','package':'LPA'}, inplace = True) # Permanent changes

# %%
students
# Out:
#     iq  percent  LPA
# 0  100       80   10
# 1  120       50    7
# 2   80       70   14
# 3   90      100    2
# 4    0        0    0
# 5    0        0    0

# %% [markdown]
# #### Math Methods

# %%
# Sum -> axis argument
students.sum()
# Out:
# iq         390
# percent    300
# LPA         33
# dtype: int64

# %%
students
# Out:
#     iq  percent  LPA
# 0  100       80   10
# 1  120       50    7
# 2   80       70   14
# 3   90      100    2
# 4    0        0    0
# 5    0        0    0

# %%
students.sum(axis=1)
# Out:
# 0    190
# 1    177
# 2    164
# 3    192
# 4      0
# 5      0
# dtype: int64

# %%
students.mean()
# Out:
# iq         65.0
# percent    50.0
# LPA         5.5
# dtype: float64

# %%
students.mean(axis=1)
# Out:
# 0    63.333333
# 1    59.000000
# 2    54.666667
# 3    64.000000
# 4     0.000000
# 5     0.000000
# dtype: float64

# %%
students.min()
# Out:
# iq         0
# percent    0
# LPA        0
# dtype: int64

# %%
students.max()
# Out:
# iq         120
# percent    100
# LPA         14
# dtype: int64

# %%
students
# Out:
#     iq  percent  LPA
# 0  100       80   10
# 1  120       50    7
# 2   80       70   14
# 3   90      100    2
# 4    0        0    0
# 5    0        0    0

# %%
students.median(axis=1)
# Out:
# 0    80.0
# 1    50.0
# 2    70.0
# 3    90.0
# 4     0.0
# 5     0.0
# dtype: float64

# %%
students.var()
# Out:
# iq         2710.0
# percent    1760.0
# LPA          33.5
# dtype: float64

# %%
students.std()
# Out:
# iq         52.057660
# percent    41.952354
# LPA         5.787918
# dtype: float64

# %%
students.mode()
# Out:
#    iq  percent  LPA
# 0   0        0    0

# %% [markdown]
# #### Selecting cols from a DataFrame

# %%
movies.head(3)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %%
# Single cols
movies['title_x'] # This is a Series
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
type(movies['title_x'])
# Out:
# pandas.core.series.Series

# %%
ipl['Venue']
# Out:
# 0                Narendra Modi Stadium, Ahmedabad
# 1                Narendra Modi Stadium, Ahmedabad
# 2                           Eden Gardens, Kolkata
# 3                           Eden Gardens, Kolkata
# 4                        Wankhede Stadium, Mumbai
#                           ...
# 945                                  Eden Gardens
# 946                              Wankhede Stadium
# 947                              Feroz Shah Kotla
# 948    Punjab Cricket Association Stadium, Mohali
# 949                         M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
# Multiple cols
movies[['title_x','year_of_release','actors']]
# Out:
#                                    title_x  year_of_release  \
# 0                 Uri: The Surgical Strike             2019
# 1                            Battalion 609             2019
# 2     The Accidental Prime Minister (film)             2019
# 3                          Why Cheat India             2019
# 4                          Evening Shadows             2018
# ...                                    ...              ...
# 1624                 Tera Mera Saath Rahen             2001
# 1625                  Yeh Zindagi Ka Safar             2001
# 1626                       Sabse Bada Sukh             2018
# 1627                                 Daaka             2019
# 1628                              Humsafar             2011
#
#                                                  actors
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# ...

# %%
type(movies[['title_x','year_of_release','actors']])
# Out:
# pandas.core.frame.DataFrame

# %%
movies[['actors','year_of_release','title_x']] # order will be same as you give
# Out:
#                                                  actors  year_of_release  \
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...             2019
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...             2019
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...             2019
# 3     Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...             2019
# 4     Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...             2018
# ...                                                 ...              ...
# 1624  Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...             2001
# 1625  Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...             2001
# 1626  Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...             2018
# 1627                          Gippy Grewal|Zareen Khan|             2019
# 1628                                        Fawad Khan|             2011
#
#                                    title_x
# 0                 Uri: The Surgical Strike
# ...

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
ipl[['Team1','Team2','WinningTeam']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %% [markdown]
# #### Selecting rows from a DataFrame
# - iloc - searches using index position
# - loc - searches using index labels

# %%
New_Student = {
    'name':['Rahul','Sumit','Ankit','Rohit','Archita'],
    'iq':[100,90,120,110,160],
    'marks':[80,90,100,100,95],
    'package':[8,5,7,6,14]
}
new_students = pd.DataFrame(New_Student)
new_students
# Out:
#       name   iq  marks  package
# 0    Rahul  100     80        8
# 1    Sumit   90     90        5
# 2    Ankit  120    100        7
# 3    Rohit  110    100        6
# 4  Archita  160     95       14

# %%
new_students.set_index('name') # temporary
# Out:
#           iq  marks  package
# name
# Rahul    100     80        8
# Sumit     90     90        5
# Ankit    120    100        7
# Rohit    110    100        6
# Archita  160     95       14

# %%
new_students.set_index('name',inplace=True)

# %%
new_students
# Out:
#           iq  marks  package
# name
# Rahul    100     80        8
# Sumit     90     90        5
# Ankit    120    100        7
# Rohit    110    100        6
# Archita  160     95       14

# %%
# Single row
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
movies.iloc[0]
# Out:
# title_x                                      Uri: The Surgical Strike
# imdb_id                                                     tt8291224
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y                                      Uri: The Surgical Strike
# original_title                               Uri: The Surgical Strike
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           138
# genres                                               Action|Drama|War
# imdb_rating                                                       8.4
# imdb_votes                                                      35112
# story               Divided over five chapters  the film chronicle...
# ...

# %%
movies.iloc[1]
# Out:
# title_x                                                 Battalion 609
# imdb_id                                                     tt9472208
# poster_path                                                       NaN
# wiki_link                 https://en.wikipedia.org/wiki/Battalion_609
# title_y                                                 Battalion 609
# original_title                                          Battalion 609
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           131
# genres                                                            War
# imdb_rating                                                       4.1
# imdb_votes                                                         73
# story               The story revolves around a cricket match betw...
# ...

# %%
movies.iloc[6:9]
# Out:
#                             title_x    imdb_id  \
# 6                     Fraud Saiyaan  tt5013008
# 7                        Bombairiya  tt4971258
# 8  Manikarnika: The Queen of Jhansi  tt6903440
#
#                                          poster_path  \
# 6  https://upload.wikimedia.org/wikipedia/en/thum...
# 7  https://upload.wikimedia.org/wikipedia/en/thum...
# 8  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 6        https://en.wikipedia.org/wiki/Fraud_Saiyaan
# 7           https://en.wikipedia.org/wiki/Bombairiya
# 8  https://en.wikipedia.org/wiki/Manikarnika:_The...
#
#                             title_y                    original_title  \
# 6                     Fraud Saiyaan                     Fraud Saiyyan
# 7                        Bombairiya                        Bombairiya
# 8  Manikarnika: The Queen of Jhansi  Manikarnika: The Queen of Jhansi
#
# ...

# %%
# Fancy indexing
movies.iloc[[0,5,6]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 5               Soni (film)  tt6078866
# 6             Fraud Saiyaan  tt5013008
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
# 6  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 5          https://en.wikipedia.org/wiki/Soni_(film)
# 6        https://en.wikipedia.org/wiki/Fraud_Saiyaan
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 5                      Soni                      Soni         0
# 6             Fraud Saiyaan             Fraud Saiyyan         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %%
# loc -> index ke label ke hisaab se
new_students
# Out:
#           iq  marks  package
# name
# Rahul    100     80        8
# Sumit     90     90        5
# Ankit    120    100        7
# Rohit    110    100        6
# Archita  160     95       14

# %%
new_students.loc['Rahul']
# Out:
# iq         100
# marks       80
# package      8
# Name: Rahul, dtype: int64

# %%
new_students.loc['Sumit':'Rohit'] # Slicing : last waala is included in this case
# Out:
#         iq  marks  package
# name
# Sumit   90     90        5
# Ankit  120    100        7
# Rohit  110    100        6

# %%
new_students.loc['Sumit':'Rohit':2]
# Out:
#         iq  marks  package
# name
# Sumit   90     90        5
# Rohit  110    100        6

# %%
new_students.loc[['Ankit','Archita']]
# Out:
#           iq  marks  package
# name
# Ankit    120    100        7
# Archita  160     95       14

# %%
# iloc is also valid
new_students.iloc[0]
# Out:
# iq         100
# marks       80
# package      8
# Name: Rahul, dtype: int64

# %%
new_students.iloc[0:3]
# Out:
#         iq  marks  package
# name
# Rahul  100     80        8
# Sumit   90     90        5
# Ankit  120    100        7

# %% [markdown]
# #### Selecting both rows and cols

# %%
movies.head(3)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %%
# I want only first three columns of first three movies
movies.iloc[0:3,0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[0:2,'title_x':'poster_path']
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# #### Filtering a DataFrame

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
# Find all the final winners : Season -> MatchNumber(Final) -> Winner
ipl['MatchNumber']=='Final'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Name: MatchNumber, Length: 950, dtype: bool

# %%
mask=ipl['MatchNumber']=='Final'
new_df = ipl[mask]
new_df
# Out:
#           ID          City        Date   Season MatchNumber  \
# 0    1312200     Ahmedabad  2022-05-29     2022       Final
# 74   1254117         Dubai  2021-10-15     2021       Final
# 134  1237181           NaN  2020-11-10  2020/21       Final
# 194  1181768     Hyderabad  2019-05-12     2019       Final
# 254  1136620        Mumbai  2018-05-27     2018       Final
# 314  1082650     Hyderabad  2017-05-21     2017       Final
# 373   981019     Bangalore  2016-05-29     2016       Final
# 433   829823       Kolkata  2015-05-24     2015       Final
# 492   734049     Bangalore  2014-06-01     2014       Final
# 552   598073       Kolkata  2013-05-26     2013       Final
# 628   548381       Chennai  2012-05-27     2012       Final
# 702   501271       Chennai  2011-05-28     2011       Final
# 775   419165        Mumbai  2010-04-25  2009/10       Final
# 835   392239  Johannesburg  2009-05-24     2009       Final
# 892   336040        Mumbai  2008-06-01  2007/08       Final
#
# ...

# %%
new_df[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# One liner
ipl[ipl['MatchNumber']=='Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# How many super over finishes have occured
ipl[ipl['SuperOver']=='Y'].shape
# Out:
# (14, 20)

# %%
# How many super over finishes have occured
ipl[ipl['SuperOver']=='Y'].shape[0]
# Out:
# 14

# %%
# How many matches has MI won in Kolkata
ipl[ipl["City"]=='Kolkata']
# Out:
#           ID     City        Date   Season  MatchNumber  \
# 2    1312198  Kolkata  2022-05-25     2022   Eliminator
# 3    1312197  Kolkata  2022-05-24     2022  Qualifier 1
# 207  1178422  Kolkata  2019-04-28     2019           47
# 211  1178418  Kolkata  2019-04-25     2019           43
# 219  1178410  Kolkata  2019-04-19     2019           35
# ..       ...      ...         ...      ...          ...
# 908   336025  Kolkata  2008-05-18  2007/08           41
# 915   336017  Kolkata  2008-05-13  2007/08           35
# 922   336010  Kolkata  2008-05-08  2007/08           29
# 934   335997  Kolkata  2008-04-29  2007/08           16
# 945   335986  Kolkata  2008-04-20  2007/08            4
#
#                            Team1                        Team2  \
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 207        Kolkata Knight Riders               Mumbai Indians
# ...

# %%
ipl[(ipl["City"]=='Kolkata') & (ipl["WinningTeam"]=='Mumbai Indians')] # Use bitwise and as in both cases I shall be getting a boolean series
# Out:
#           ID     City        Date   Season  MatchNumber  \
# 273  1136601  Kolkata  2018-05-09     2018           41
# 320  1082644  Kolkata  2017-05-13     2017           54
# 428   980909  Kolkata  2016-04-13     2016            5
# 433   829823  Kolkata  2015-05-24     2015        Final
# 552   598073  Kolkata  2013-05-26     2013        Final
# 553   598072  Kolkata  2013-05-24     2013  Qualifier 2
# 595   598029  Kolkata  2013-04-24     2013           33
# 646   548363  Kolkata  2012-05-12     2012           58
# 706   501267  Kolkata  2011-05-22     2011           70
# 934   335997  Kolkata  2008-04-29  2007/08           16
#
#                      Team1                  Team2         Venue  \
# 273         Mumbai Indians  Kolkata Knight Riders  Eden Gardens
# 320  Kolkata Knight Riders         Mumbai Indians  Eden Gardens
# 428  Kolkata Knight Riders         Mumbai Indians  Eden Gardens
# 433         Mumbai Indians    Chennai Super Kings  Eden Gardens
# ...

# %%
ipl[(ipl["City"]=='Kolkata') & (ipl["WinningTeam"]=='Mumbai Indians')].shape[0]
# Out:
# 10

# %%
# Toss winner is match winner in percentage
ipl.head(3)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# ...

# %%
ipl[(ipl['TossWinner'])==(ipl['WinningTeam'])]
# Out:
#           ID         City        Date   Season  MatchNumber  \
# 1    1312199    Ahmedabad  2022-05-27     2022  Qualifier 2
# 3    1312197      Kolkata  2022-05-24     2022  Qualifier 1
# 5    1304115       Mumbai  2022-05-21     2022           69
# 8    1304112  Navi Mumbai  2022-05-18     2022           66
# 11   1304109       Mumbai  2022-05-15     2022           63
# ..       ...          ...         ...      ...          ...
# 935   335996    Bangalore  2008-04-28  2007/08           15
# 937   335994       Mumbai  2008-04-27  2007/08           14
# 939   335992    Bangalore  2008-04-26  2007/08           12
# 941   335990    Hyderabad  2008-04-24  2007/08            9
# 948   335983   Chandigarh  2008-04-19  2007/08            2
#
#                            Team1                  Team2  \
# 1    Royal Challengers Bangalore       Rajasthan Royals
# 3               Rajasthan Royals         Gujarat Titans
# 5                 Delhi Capitals         Mumbai Indians
# ...

# %%
ipl[(ipl['TossWinner'])==(ipl['WinningTeam'])].shape[0]
# Out:
# 489

# %%
(ipl[(ipl['TossWinner'])==(ipl['WinningTeam'])].shape[0]/ipl.shape[0])*100
# Out:
# 51.473684210526315

# %%
# Movies with rating higher than 8 and votes>10000
movies.sample(3)
# Out:
#                   title_x    imdb_id  \
# 488   Station (2014 film)  tt2191164
# 1221  Barsaat (2005 film)  tt0444767
# 942           Sankat City  tt1252614
#
#                                             poster_path  \
# 488   https://upload.wikimedia.org/wikipedia/en/thum...
# 1221  https://upload.wikimedia.org/wikipedia/en/thum...
# 942   https://upload.wikimedia.org/wikipedia/en/0/01...
#
#                                               wiki_link  \
# 488     https://en.wikipedia.org/wiki/Station:_The_Film
# 1221  https://en.wikipedia.org/wiki/Barsaat_(2005_film)
# 942           https://en.wikipedia.org/wiki/Sankat_City
#
#                             title_y                 original_title  is_adult  \
# 488                         Station                        Station         0
# 1221  A Sublime Love Story: Barsaat  A Sublime Love Story: Barsaat         0
# 942                     Sankat City                    Sankat City         0
#
# ...

# %%
movies[(movies['imdb_rating']>8) & (movies['imdb_votes']>10000)]
# Out:
#                           title_x     imdb_id  \
# 0        Uri: The Surgical Strike   tt8291224
# 11                      Gully Boy   tt2395469
# 37              Article 15 (film)  tt10324144
# 40                Super 30 (film)   tt7485048
# 143                       Tumbbad   tt8239946
# 146                     Andhadhun   tt8108198
# 325              Pink (2016 film)   tt5571734
# 354                 Dangal (film)   tt5074352
# 418                        Masaan   tt4635372
# 426          Drishyam (2015 film)   tt4430212
# 436                 Talvar (film)   tt4934950
# 469             Queen (2014 film)   tt3322420
# 536                 Haider (film)   tt3390572
# 566                   Ugly (film)   tt2882328
# 567                     PK (film)   tt2338151
# 589                  Vishwaroopam   tt2199711
# 612            Bhaag Milkha Bhaag   tt2356180
# 638                 Shahid (film)   tt2181831
# 668       Paan Singh Tomar (film)   tt1620933
# ...

# %%
movies[(movies['imdb_rating']>8) & (movies['imdb_votes']>10000)].shape[0]
# Out:
# 43

# %%
# Action movies rating higher than 7.5
movies.sample(5)
# Out:
#                    title_x    imdb_id  \
# 866                 Lamhaa  tt1309561
# 1220              7½ Phere  tt0453582
# 86    Love per Square Foot  tt7853242
# 1231    Chaahat – Ek Nasha  tt0447890
# 457                 Gunday  tt2574698
#
#                                             poster_path  \
# 866   https://upload.wikimedia.org/wikipedia/en/thum...
# 1220  https://upload.wikimedia.org/wikipedia/en/thum...
# 86    https://upload.wikimedia.org/wikipedia/en/3/3d...
# 1231  https://upload.wikimedia.org/wikipedia/en/thum...
# 457   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 866                https://en.wikipedia.org/wiki/Lamhaa
# 1220        https://en.wikipedia.org/wiki/7%C2%BD_Phere
# 86    https://en.wikipedia.org/wiki/Love_Per_Square_...
# 1231  https://en.wikipedia.org/wiki/Chaahat_%E2%80%9...
# 457                https://en.wikipedia.org/wiki/Gunday
#
#                                   title_y  \
# ...

# %%
# genres have multiple values for an item
movies['genres'].split('|')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8952\962692440.py in ?()
#       1 # genres have multiple values for an item
# ----> 2 movies['genres'].split('|')
#
# ~\Downloads\Practice\Python\conda_env\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
movies['genres'].str

# %%
movies['genres'].str.split('|')
# Out:
# 0       [Action, Drama, War]
# 1                      [War]
# 2         [Biography, Drama]
# 3             [Crime, Drama]
# 4                    [Drama]
#                 ...
# 1624                 [Drama]
# 1625                 [Drama]
# 1626         [Comedy, Drama]
# 1627                [Action]
# 1628        [Drama, Romance]
# Name: genres, Length: 1629, dtype: object

# %%
movies['genres'].str.split('|').apply(lambda x:'Action' in x)
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627     True
# 1628    False
# Name: genres, Length: 1629, dtype: bool

# %%
mask1 = movies['genres'].str.split('|').apply(lambda x:'Action' in x)  # lambda arguments : expression
mask2 = movies['imdb_rating']>7.5
movies[mask1 & mask2]
# Out:
#                             title_x    imdb_id  \
# 0          Uri: The Surgical Strike  tt8291224
# 41             Family of Thakurganj  tt8897986
# 84                        Mukkabaaz  tt7180544
# 106                           Raazi  tt7098658
# 110   Parmanu: The Story of Pokhran  tt6826438
# 112         Bhavesh Joshi Superhero  tt6129302
# 169                The Ghazi Attack  tt6299040
# 219                Raag Desh (film)  tt6080746
# 258                   Irudhi Suttru  tt5310090
# 280                       Laal Rang  tt5600714
# 297                     Udta Punjab  tt4434004
# 354                   Dangal (film)  tt5074352
# 362               Bajrangi Bhaijaan  tt3863552
# 365          Baby (2015 Hindi film)  tt3848892
# 393      Detective Byomkesh Bakshy!  tt3447364
# 449               Titli (2014 film)  tt3019620
# 536                   Haider (film)  tt3390572
# 589                    Vishwaroopam  tt2199711
# 625                     Madras Cafe  tt2855648
# ...

# %%
movies[mask1 & mask2].shape[0]
# Out:
# 33

# %%
mask = movies['genres'].str.contains('Action')

# %%
mask
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627     True
# 1628    False
# Name: genres, Length: 1629, dtype: bool

# %%
# Write a function that can return the track record of 2 teams against each other

# %% [markdown]
# #### Adding new cols

# %%
# Completely new
movies.sample(2)
# Out:
#                    title_x    imdb_id  \
# 1621               Tum Bin  tt0290326
# 973   Raat Gayi Baat Gayi?  tt1210356
#
#                                             poster_path  \
# 1621  https://upload.wikimedia.org/wikipedia/en/thum...
# 973   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1621              https://en.wikipedia.org/wiki/Tum_Bin
# 973   https://en.wikipedia.org/wiki/Raat_Gayi_Baat_G...
#
#                                title_y                    original_title  \
# 1621  Tum Bin...: Love Will Find a Way  Tum Bin...: Love Will Find a Way
# 973               Raat Gayi Baat Gayi?              Raat Gayi Baat Gayi?
#
#       is_adult  year_of_release runtime         genres  imdb_rating  \
# 1621         0             2001     158  Drama|Romance          7.5
# 973          0             2009      \N   Comedy|Drama          6.3
#
# ...

# %%
movies['Country'] = 'India'

# %%
movies.head(3)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %%
# From existing columns
movies["actors"].str.split('|').apply(lambda x:x[0]) # Error due to missing values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[209], line 2
#       1 # From existing columns
# ----> 2 movies["actors"].str.split('|').apply(lambda x:x[0])
#
# File ~\Downloads\Practice\Python\conda_env\Lib\site-packages\pandas\core\series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# ...

# %%
# dropna removes all the missing value
movies.dropna(inplace=True)

# %%
movies.sample(3)
# Out:
#               title_x    imdb_id  \
# 162          Ok Jaanu  tt5764024
# 1202   Shikhar (film)  tt0475627
# 1511  Bomb the System  tt0337585
#
#                                             poster_path  \
# 162   https://upload.wikimedia.org/wikipedia/en/thum...
# 1202  https://upload.wikimedia.org/wikipedia/en/d/de...
# 1511  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link          title_y  \
# 162          https://en.wikipedia.org/wiki/Ok_Jaanu     Okay Darling
# 1202   https://en.wikipedia.org/wiki/Shikhar_(film)          Shikhar
# 1511  https://en.wikipedia.org/wiki/Bomb_the_System  Bomb the System
#
#        original_title  is_adult  year_of_release runtime         genres  \
# 162          OK Jaanu         0             2017     135  Drama|Romance
# 1202          Shikhar         0             2005     162          Drama
# 1511  Bomb the System         0             2002      91   Action|Drama
#
# ...

# %%
movies["Lead_Actor"] = movies["actors"].str.split('|').apply(lambda x:x[0])

# %%
movies["actors"].str.split('|').apply(lambda x:x[0]).shape
# Out:
# (298,)

# %%
movies.sample(1)
# Out:
#             title_x    imdb_id  \
# 1184  Kabul Express  tt0770214
#
#                                             poster_path  \
# 1184  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                         wiki_link        title_y  \
# 1184  https://en.wikipedia.org/wiki/Kabul_Express  Kabul Express
#
#      original_title  is_adult  year_of_release runtime  \
# 1184  Kabul Express         0             2006     105
#
#                       genres  imdb_rating  imdb_votes  \
# 1184  Adventure|Comedy|Drama          6.8        2923
#
#                                                   story  \
# 1184  Suhel (John Abraham) and Jai (Arshad Warsi) - ...
#
#                                                 summary  \
# 1184  A thrilling story spanning 48 hours of five in...
#
#                                                 tagline  \
# 1184  Two Indians| an American| one Afghan and a Pak...
#
#                                                  actors  \
# ...

# %% [markdown]
# #### Important DataFrame Functions

# %%
# astype
ipl.info() # Look at the memory space
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl["ID"].astype('int32')
# Out:
# 0      1312200
# 1      1312199
# 2      1312198
# 3      1312197
# 4      1304116
#         ...
# 945     335986
# 946     335985
# 947     335984
# 948     335983
# 949     335982
# Name: ID, Length: 950, dtype: int32

# %%
ipl["ID"] = ipl["ID"].astype('int32')

# %%
ipl.info() # See change in the memory space
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['Season'] = ipl['Season'].astype('category') # Use category for the data which will repeat

# %%
ipl.info() # Change in memory space
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['Team1'] = ipl['Team1'].astype('category')
ipl['Team2'] = ipl['Team2'].astype('category')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...
